# %% [markdown]
# <a href="https://colab.research.google.com/github/barzansaeedpour/cancer-detection/blob/main/cancer_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import the packages

# %%
# Section1 : Import libraries
# Importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading the dataset
#
# Please download the dataset from the githup repository and upload it here.

# %%
## Section 2: Loading the data
cancer =  pd.read_csv("data.csv",index_col=False)

# %%
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
d = cancer["diagnosis"].value_counts()
keys = d.keys()
values = d.values
for k in keys:
    plt.bar(k,d[k], label = k)
plt.legend()
plt.xlabel('Values')
plt.ylabel('Count')
plt.xticks(keys)
plt.yticks(values)
plt.title('Count of different values')
# Out:
# Text(0.5, 1.0, 'Count of different values')

# %%
# Drop non-numeric columns and calculate correlation
cor = cancer.select_dtypes(include=['float64', 'int64']).corr()
plt.figure(figsize=(7,7))
sns.heatmap(cor, annot=True, fmt=".0%")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## preprocessing
#
# We need to do some preprocessing steps:
#
# 1. Removing the `id` column
# 2. Encoding the `diagnosis` column

# %%
# The dataset before preprocessing
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### removing useless features
# The id is an unneeded feature for machine learning models

# %%
# Dropping the 'id' column
cancer.drop("id", axis=1, inplace= True)

# %% [markdown]
# ### Encoding
# As the diagnosis column is in string format (we need to work with numeric data) we use `LabelEncoder` to encode it to binary numbers.

# %%
# Encoding the 'diagnosis' column
LabelEncoder_y = LabelEncoder()
cancer['diagnosis'] = LabelEncoder_y.fit_transform(cancer['diagnosis'].values)

# %%
# The dataset after preprocessing
cancer.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### Train & Test Split

# %%
# Splitting the dataset into dependent (X) and independent (Y) variables
x = cancer.loc[:, cancer.columns != 'diagnosis']
y = cancer['diagnosis']

# %%
# Conver x and y to numerical arrays
x = x.values
y = y.values

# %%
# Splitting the dataset into training and testing sets
x_train,x_test,y_train, y_test = train_test_split (x,y,test_size = 0.25, random_state=0)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (426, 30)
# y_train shape: (426,)
# x_test shape: (143, 30)
# y_test shape: (143,)

# %% [markdown]
# ### Feature Scaling
# - What is feature scaling?
#
# Feature scaling is a method used to normalize the range of independent
# variables or features of data. In data processing, it is also known as
# data normalization and is generally performed during the data preprocessing
# step.
#
# - Advantages?
#
# Few advantages of normalizing the data are as follows:
#
# 1. It makes your training faster.
# 2. It prevents you from getting stuck in local optima.
# 3. It gives you a better error surface shape.
# 4. Wweight decay and bayes optimization can be done more conveniently.
#
# Hovewer, there are few algorithms such as Logistic Regression and Decision Trees that are not affected by scaling of input data. With regard to neural networks it makes a difference.
#
# - How it works?
#  - The **`StandardScaler`** class standardizes features by removing the mean and scaling them to have unit variance. Here's how it works:
#
#     - For each feature, it calculates the **standard score** (also known as **Z-score**) of a sample.
#     - The standard score of a sample **x** is calculated as: **z = (x - u) / s**, where:
#         - **u** is the mean of the training samples (or zero if `with_mean=False`).
#         - **s** is the standard deviation of the training samples (or one if `with_std=False`).
#     - Centering and scaling happen independently for each feature based on the relevant statistics computed from the training set.
#     - The mean and standard deviation are stored to be used later for transforming new data.

# %%
# data before scaling
x_train[0]
# Out:
# array([1.185e+01, 1.746e+01, 7.554e+01, 4.327e+02, 8.372e-02, 5.642e-02,
#        2.688e-02, 2.280e-02, 1.875e-01, 5.715e-02, 2.070e-01, 1.238e+00,
#        1.234e+00, 1.388e+01, 7.595e-03, 1.500e-02, 1.412e-02, 8.578e-03,
#        1.792e-02, 1.784e-03, 1.306e+01, 2.575e+01, 8.435e+01, 5.178e+02,
#        1.369e-01, 1.758e-01, 1.316e-01, 9.140e-02, 3.101e-01, 7.007e-02])

# %%
# Perform the feature Scaling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# data after scaling
x_train[0]
# Out:
# array([-0.65079907, -0.43057322, -0.68024847, -0.62698309, -0.91381897,
#        -0.93335153, -0.78763077, -0.67944444,  0.25404078, -0.79877182,
#        -0.68958948,  0.04723809, -0.78036299, -0.55337361,  0.21546423,
#        -0.59450332, -0.55964264, -0.52889336, -0.30718648, -0.73414209,
#        -0.6661438 ,  0.01849243, -0.68117939, -0.63150142,  0.19196229,
#        -0.50775064, -0.69592933, -0.36433881,  0.32349851, -0.7578486 ])

# %% [markdown]
# ## Building the models

# %% [markdown]
# ### Train the models

# %%
def models(x_train, y_train):
    # Logistic Regression
    log = LogisticRegression(random_state=0)
    log.fit(x_train, y_train)

    # Decision Tree
    tree = DecisionTreeClassifier(criterion="entropy", random_state=0)
    tree.fit(x_train, y_train)

    # Random Forest
    forest = RandomForestClassifier(n_estimators=50, criterion="entropy", random_state=0)
    forest.fit(x_train, y_train)

    # Printing the accuracy of each model
    print(f"Logistic regression - train accuracy: {log.score(x_train, y_train)}")
    print(f"Decision tree - train accuracy:       {tree.score(x_train, y_train)}")
    print(f"Random forest - train accuracy:       {forest.score(x_train, y_train)}")

    output = [
           {
            'name' : 'Logistic Regression',
            'model': log
            },
           {
            'name' : 'Decision Tree',
            'model': tree
            },
           {
            'name' : 'Random Forest',
            'model': forest
            },
    ]
    return output

trained_models = models(x_train, y_train)
# Out:
# Logistic regression - train accuracy: 0.9906103286384976
# Decision tree - train accuracy:       1.0
# Random forest - train accuracy:       1.0

# %% [markdown]
# ### Test and Evaluate the models

# %%
for model in trained_models:

    print(f"Model: {model['name']}")
    print("Classification Report: ")
    print(classification_report(y_test, model['model'].predict(x_test)))
    print("Accuracy Score: ", accuracy_score(y_test, model['model'].predict(x_test)))
    print("******************************************************")
# Out:
# Model: Logistic Regression
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        90
#            1       0.94      0.94      0.94        53
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# Accuracy Score:  0.958041958041958
# ******************************************************
# Model: Decision Tree
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        90
#            1       0.93      0.96      0.94        53
#
#     accuracy                           0.96       143
#    macro avg       0.95      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# Accuracy Score:  0.958041958041958
# ******************************************************
# Model: Random Forest
# ...

# %%
# Assuming 'cancer' is your DataFrame used for training
print(cancer.columns)  # Print all the columns to see which features were used
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
import numpy as np

# Correct sample input with 30 features only (replace values as needed)
sample_input = np.array([[13.5, 20.0, 88.0, 500.0, 0.083, 0.21, 0.09, 
                          0.05, 0.02, 0.06, 0.063, 1.5, 2.0, 15.0, 
                          200.0, 0.02, 0.04, 0.02, 0.005, 0.05, 
                          14.0, 22.0, 90.0, 600.0, 0.1, 0.15, 
                          0.2, 0.03, 0.2, 0.01]])

# Print the shape of sample_input
print("Sample Input Shape:", sample_input.shape)

# Ensure that you have 30 features
if sample_input.shape[1] != 30:
    raise ValueError(f"Expected 30 features, but got {sample_input.shape[1]} features.")
# Out:
# Sample Input Shape: (1, 30)

# %%
for model in trained_models:
    model_name = model['name']
    
    # Make predictions using the corrected sample input
    prediction = model['model'].predict(sample_input)

    print(f"Model: {model_name}")
    print(f"Predicted Class: {'Malignant' if prediction[0] == 1 else 'Benign'}")
    print("******************************************************")
# Out:
# Model: Logistic Regression
# Predicted Class: Malignant
# ******************************************************
# Model: Decision Tree
# Predicted Class: Malignant
# ******************************************************
# Model: Random Forest
# Predicted Class: Malignant
# ******************************************************
