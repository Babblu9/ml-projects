# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('drug200.csv')
data.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
new_data = data.drop(['Sex'],axis=1)
new_data.head()
# Out:
#    Age      BP Cholesterol  Na_to_K   Drug
# 0   23    HIGH        HIGH   25.355  drugY
# 1   47     LOW        HIGH   13.093  drugC
# 2   47     LOW        HIGH   10.114  drugC
# 3   28  NORMAL        HIGH    7.798  drugX
# 4   61     LOW        HIGH   18.043  drugY

# %%
full_data = new_data.copy()
full_data['BP']=full_data['BP'].map({'LOW':0,'HIGH':2,'NORMAL':1})
full_data['Cholesterol']=full_data['Cholesterol'].map({'LOW':0,'HIGH':2,'NORMAL':1})
full_data['Drug']=full_data['Drug'].map({'drugY':0,'drugX':1,'drugA':2,'drugB':3,'drugC':4})

full_data.head()
# Out:
#    Age  BP  Cholesterol  Na_to_K  Drug
# 0   23   2            2   25.355     0
# 1   47   0            2   13.093     4
# 2   47   0            2   10.114     4
# 3   28   1            2    7.798     1
# 4   61   0            2   18.043     0

# %%
x = full_data[['Age','BP','Cholesterol','Na_to_K']]
y = full_data['Drug']

# %%
full_data.isnull().sum()
# Out:
# Age            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
regressor.predict([[22,1,1,10]])
# Out:
# c:\Users\Sai Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1.])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state = 10)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(model.score(x_test,y_test)*100)
# Out:
# 100.0

# %%
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_predict,y_test)

# %%
plt.figure(figsize=(13,9))
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
